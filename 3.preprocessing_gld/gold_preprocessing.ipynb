# %%
# Load libraries
from pyspark.sql import functions as F
from delta.tables import DeltaTable

# %% [markdown]
# ##

# %% [markdown]
# # Gold Level
# silver_df = spark.sql(f'select * from {catalog}.{silver_schema}.{data_source}')
# display(silver_df.limit(3))
# %md
# 1. Gender (BENE_SEX_IDENT_CD)
#
# This is the most frequent place you will see these values.
#
# 1: Male
#
# 2: Female
#
# 0: Unknown
#
# 2. Race (BENE_RACE_CD)
#
# 1: White
#
# 2: Black
#
# 3: Other
#
# 4: Asian
#
# 5: Hispanic
#
# 6: North American Native
#
# 0: Unknown
#
# 3. Chronic Condition Flags (SP_ prefixed columns)
#
# The SynPUF dataset includes several "Segment-Specificed" (SP) flags for conditions like Alzheimer's (SP_ALZHDMTA), Diabetes (SP_DIABETES), and Heart Failure (SP_CHF). For these columns, the values are:
#
# 1: Yes (Condition is present)
#
# 2: No (Condition is not present)
